# %%
import numpy as np

# %%
temp = np.array([1, 2, 3]) 
min = np.argmin(abs(temp - 3))
temp[min]
# Out:
# np.int64(3)

# %%
[1, 1, 2, 3, 4, 1].count(1)
# Out:
# 3

# %%
import numpy as np

temp = np.array([1, 1, 2, 3]) 
temp += temp

# %%
rotation_count = [0, 2, 0, 3, 4]
sum(1 for x in rotation_count if x > 0)
# Out:
# 3
